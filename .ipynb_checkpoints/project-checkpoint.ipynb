# %%
import OpenDartReader
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
API_KEY = 'e0646f27a0bad27c49544a269362fd7e844913b0'
dart = OpenDartReader(API_KEY)

# %%
df = pd.read_csv('./data/data_3322_20220211.csv', encoding='euc-kr')
df
# Out:
#               표준코드    단축코드            한글 종목명  한글 종목약명  \
# 0     KR7098120009  098120      (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1     KR7131100000  131100         (주)스카이이앤엠   스카이이앤엠
# 2     KR7009520008  009520          (주)포스코엠텍    포스코엠텍
# 3     KR7095570008  095570         AJ네트웍스보통주   AJ네트웍스
# 4     KR7006840003  006840          AK홀딩스보통주    AK홀딩스
# ...            ...     ...               ...      ...
# 2609  KR7000542001  000547  흥국화재해상보험2우선주(신형)  흥국화재2우B
# 2610  KR7000540005  000540       흥국화재해상보험보통주     흥국화재
# 2611  KR7003280005  003280           흥아해운보통주     흥아해운
# 2612  KR7037440005  037440        희림종합건축사사무소       희림
# 2613  KR7238490007  238490                힘스       힘스
#
#                                영문 종목명         상장일    시장구분 증권구분          소속부  \
# 0     Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부
# 1                   SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)
# 2               POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부
# ...

# %%
# '11013'=1분기보고서, '11012' =반기보고서, '11014'=3분기보고서, '11011'=사업보고서
reprt_code = ['11013', '11012', '11014', '11011']

# %%
# 2020-07-01 부터 현재까지 모든 회사의 정기보고서
df = dart.finstate('삼성전자', 2019)

# %%
# df.to_excel(f"stock_excel_files/{name}.xlsx")
df
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 1   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 2   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 3   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 4   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 5   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 6   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 7   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 8   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 9   20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# 10  20200330003851      11011      2019  00126380     005930    CFS  연결재무제표
# ...

# %%
df.단축코드[]
# Out:
# 0       098120
# 1       131100
# 2       009520
# 3       095570
# 4       006840
#          ...
# 2609    000547
# 2610    000540
# 2611    003280
# 2612    037440
# 2613    238490
# Name: 단축코드, Length: 2614, dtype: object

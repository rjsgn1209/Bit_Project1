# %%
import pandas as pd
import numpy as np
import re

# %%
import os
path = "./fsdata"
file_list = os.listdir(path)
file_list[173]
# Out:
# '가비아.xlsx'

# %%
con_df_li = []
count = 0
error_li = []
for i, f in enumerate(file_list):
    df = pd.read_excel(f"./fsdata/{f}", sheet_name=None)
    
    if df['Data_cis'].iloc[:, 1][0] == "label_ko":
        label_col = 1
    else:
        label_col = 2
    if 'Data_is' in df.keys():
        sheet_name = 'Data_is'
    else:
        sheet_name = 'Data_cis'
        
    # 자본금   
    df1 = df['Data_bs'][df['Data_bs'].iloc[:, label_col].str.contains('자본금').fillna(False)] 
    if len(df1) > 1:
        df1 = df['Data_bs'][df['Data_bs'].iloc[:, label_col] == '자본금']
    elif len(df1) == 0:
        df1 = df['Data_bs'][df['Data_bs'].iloc[:, 1].str.contains('ifrs-full_IssuedCapital').fillna(False)] 
        if len(df1) == 0:
            df1 = df['Data_bs'][df['Data_bs'].iloc[:, 1].isin(['ifrs_EquityAttributableToOwnersOfParent']).fillna(False)] 
    if len(df1) == 0:
        df1 = df['Data_bs'][df['Data_bs'].iloc[:, label_col].isin(['납입자본'])] 
        
    # 자산총계
    df2 = df['Data_bs'][df['Data_bs'].iloc[:, label_col] == '자산총계']
    
    # 당기순이익
    df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].str.contains('당기순이익').fillna(False)]
    if len(df3) > 1:
        df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].isin(['연결당기순이익', '당기순이익(손실)', '당기순이익', '당기순손익', '당기순손실'])]
        if len(df3) == 0:
            df3 = df['Data_cf'][df['Data_cf'].iloc[:, label_col].isin(['당기순이익(손실)'])]
            
    elif len(df3) == 0:
        df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].isin(['당기순손익', '당기순손실', '당기의 순이익', '계속영업이익(손실)'])]
        if len(df3) == 0:
            df3 = df[sheet_name][df[sheet_name].iloc[:, 1].str.contains('당기순이익').fillna(False)]
        if len(df3) == 0:
            df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].str.contains('당기손익').fillna(False)]
        
    if len(df3) > 1:
        df3 = df3[df3.isna().sum(axis = 1) == df3.isna().sum(axis = 1).min()]
    
    # 영업활동 현금흐름
    regex = r'[1-9]?[A-z]?[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]?\s?영업\s?활동?([가-힣]+)?(\s+[가-힣]+\s+)?\s?현금\s?흐름'
    df4 = df['Data_cf'][df['Data_cf'].iloc[:, 1].str.contains('ifrs-full_CashFlowsFromUsedInOperatingActivities').fillna(False)]                          
                                                               
    if len(df4) == 0:
        df4 = df['Data_cf'][df['Data_cf'].iloc[:, label_col].str.contains(regex).fillna(False)]
        if len(df4) > 1:
            df4 = df['Data_cf'][df['Data_cf'].iloc[:, 1].isin(['ifrs_CashFlowsFromUsedInOperatingActivities']).fillna(False)]
            if len(df4) > 0:
                df4 = df['Data_cf'][df['Data_cf'].iloc[:, 1].str.contains(r'영업\s활동\s현금\s흐름').fillna(False)]
    
    # 영업이익
    df5 = df[sheet_name][df[sheet_name].iloc[:, 1].str.contains('dart_OperatingIncomeLoss').fillna(False)]
    if len(df5) == 0:
        df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains(r'영업\s?이익').fillna(False)]
        if len(df5) == 0:
            df5 = df[sheet_name][df[sheet_name].iloc[:, 1].str.contains(r'영업\s?이익').fillna(False)]
            if len(df5) == 0:
                sheet_name = 'Data_cis'
                df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains(r'영업\s?이익').fillna(False)]
                
    # 매출액
   
    df6 = df[sheet_name][df[sheet_name].iloc[:, 1].str.contains('ifrs-full_Revenue').fillna(False)] 
    if len(df6) == 0: # ID로 구하기
        df6 = df[sheet_name][df[sheet_name].iloc[:, 1].isin(['ifrs-full_Revenue', 'ifrs_Revenue'])]
    if len(df6) == 0: # Name으로 구하기
        df6 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('매출액').fillna(False)]
        if len(df6) == 0:
            df6 = df[sheet_name][df[sheet_name].iloc[:, label_col].isin(['매출'])]
       
        if len(df6) > 1: 
            df6 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains(r'Ⅰ.매출액.*').fillna(False)]

            
    if len(df6) == 0: # name col다른 애들 col변경해서 잡기
        
        df6 = df[sheet_name][df[sheet_name].iloc[:, 1].str.contains('매출액').fillna(False)]
        if len(df6) > 1:
            df6 = df[sheet_name][df[sheet_name].iloc[:, 1].isin(['매출액'])]
        if len(df6) == 0:
            df6 = df[sheet_name][df[sheet_name].iloc[:, 1].isin(['I.매출'])]
        if len(df6) == 0:
            df6 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].str.contains('매출액').fillna(False)]

    if len(df6) == 0:   # 매출액 없는녀석 영업수익 구하기
        df6 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('영업수익').fillna(False)]
        if len(df6) > 1: # name으로 isin
            df6 = df[sheet_name][df[sheet_name].iloc[:, 1].isin(['I.영업수익', '영업수익'])]
            if len(df6) > 1:
                df6 = df[sheet_name][df[sheet_name].iloc[:, 1].isin(['I.영업수익', '영업수익'])]
    elif len(df6) > 1:
        df6 = df[sheet_name][df[sheet_name].iloc[:, 1].isin(['ifrs-full_Revenue', 'ifrs_Revenue'])]
    
#     df1 = concat_df(df1, '자본총계', label_col)
#     df2 = concat_df(df2, '자산총계', label_col)
#     df3 = concat_df(df3, '당기순이익', label_col)
#     df4 = concat_df(df4, '영업활동현금흐름', label_col)
#     df5 = concat_df(df5, '영업이익', label_col)
#     df6 = concat_df(df6, '매출액', label_col)
#     # print(df1, df2, df3, df4, df5, df6)
#     con_df = pd.concat([df1, df2, df3, df4, df5, df6])
#     con_df_li.append(con_df)


    print(i, f, len(df1), len(df2), len(df3), len(df4), len(df5), len(df6))
    if len(df1) != 1 or len(df2) != 1 or len(df3) != 1 or len(df4) != 1 or len(df5) != 1 or len(df6) != 1:
        count += 1
        error_li.append([i, f])
        print('Error')
print(error_li)
print(count)
# Out:
# 0 00568188_annual.xlsx 1 1 1 1 1 1
# 1 3S.xlsx 1 1 1 1 1 1
# 2 AJ네트웍스.xlsx 1 1 1 1 1 1
# 3 AK홀딩스.xlsx 1 1 1 1 1 1
# 4 APS홀딩스.xlsx 1 1 1 1 1 1
# 5 AP시스템.xlsx 1 1 1 1 1 1
# 6 BGF.xlsx 1 1 1 1 1 1
# 7 BGF리테일.xlsx 1 1 1 1 1 1
# 8 BNGT.xlsx 1 1 1 1 1 1
# 9 BNK금융지주.xlsx 1 1 1 1 1 1
# 10 BYC.xlsx 1 1 1 1 1 1
# 11 CJ CGV.xlsx 1 1 1 1 1 1
# 12 CJ ENM.xlsx 1 1 1 1 1 1
# 13 CJ 바이오사이언스.xlsx 1 1 1 1 1 1
# 14 CJ.xlsx 1 1 1 1 1 1
# 15 CJ대한통운.xlsx 1 1 1 1 1 1
# 16 CJ씨푸드.xlsx 1 1 1 1 1 1
# 17 CJ제일제당.xlsx 1 1 1 1 1 1
# 18 CJ프레시웨이.xlsx 1 1 1 1 1 1
# 19 CMG제약.xlsx 1 1 1 1 1 1
# 20 CS홀딩스.xlsx 1 1 1 1 1 1
# 21 DB.xlsx 1 1 1 1 1 1
# 22 DB하이텍.xlsx 1 1 1 1 1 1
# 23 DL.xlsx 1 1 1 1 1 1
# 24 DMS.xlsx 1 1 1 1 1 1
# 25 DRB동일.xlsx 1 1 1 1 1 1
# 26 DSR.xlsx 1 1 1 1 1 1
# 27 E1.xlsx 1 1 1 1 1 1
# 28 EDGC.xlsx 1 1 1 1 1 1
# 29 EG.xlsx 1 1 1 1 1 1
# 30 EMB.xlsx 1 1 1 1 1 1
# 31 EMW.xlsx 1 1 1 1 1 1
# 32 ESR켄달스퀘어리츠.xlsx 1 1 1 1 1 1
# 33 ES큐브.xlsx 1 1 1 1 1 1
# 34 FSN.xlsx 1 1 1 1 1 1
# 35 GH신소재.xlsx 1 1 1 1 1 1
# 36 GS.xlsx 1 1 1 1 1 1
# 37 GS건설.xlsx 1 1 1 1 1 1
# 38 GS글로벌.xlsx 1 1 1 1 1 1
# 39 GS리테일.xlsx 1 1 1 1 1 1
# 40 HB솔루션.xlsx 1 1 1 1 1 1
# 41 HB테크놀러지.xlsx 1 1 1 1 1 1
# 42 HDC.xlsx 1 1 1 1 1 1
# 43 HDC랩스.xlsx 1 1 1 1 1 1
# 44 HDC현대EP.xlsx 1 1 1 1 1 1
# 45 HDC현대산업개발.xlsx 1 1 1 1 1 1
# 46 HJ중공업.xlsx 1 1 1 1 1 1
# 47 HLB.xlsx 1 1 1 1 1 1
# 48 HLB생명과학.xlsx 1 1 1 1 1 1
# 49 HLB제약.xlsx 1 1 1 1 1 1
# 50 HLB테라퓨틱스.xlsx 1 1 1 1 1 1
# 51 HMM.xlsx 1 1 1 1 1 1
# 52 HRS.xlsx 1 1 1 1 1 1
# 53 HSD엔진.xlsx 1 1 1 1 1 1
# 54 iMBC.xlsx 1 1 1 1 1 1
# 55 ISC.xlsx 1 1 1 1 1 1
# 56 ITX-AI.xlsx 1 1 1 1 1 1
# 57 JTC.xlsx 1 1 1 1 1 1
# 58 JW생명과학.xlsx 1 1 1 1 1 1
# 59 JW신약.xlsx 1 1 1 1 1 1
# 1501 호텔신라.xlsx 1 1 1 1 1 1
# 1502 홈센타홀딩스.xlsx 1 1 1 1 1 1
# 1503 홈캐스트.xlsx 1 1 1 1 1 1
# 1504 화승엔터프라이즈.xlsx 1 1 1 1 1 1
# 1505 화승코퍼레이션.xlsx 1 1 1 1 1 1
# 1506 화일약품.xlsx 1 1 1 1 1 1
# 1507 화천기공.xlsx 1 1 1 1 1 1
# 1508 환인제약.xlsx 1 1 1 1 1 1
# 1509 황금에스티.xlsx 1 1 1 1 1 1
# 1510 효성오앤비.xlsx 1 1 1 1 1 1
# 1511 효성중공업.xlsx 1 1 1 1 1 1
# 1512 효성첨단소재.xlsx 1 1 1 1 1 1
# 1513 효성티앤씨.xlsx 1 1 1 1 1 1
# 1514 효성화학.xlsx 1 1 1 1 1 1
# 1515 휘닉스소재.xlsx 1 1 1 1 1 1
# 1516 휠라홀딩스.xlsx 1 1 1 1 1 1
# 1517 휴네시온.xlsx 1 1 1 1 1 1
# 1518 휴림로봇.xlsx 1 1 1 1 1 1
# 1519 휴맥스.xlsx 1 1 1 1 1 1
# 1520 휴맥스홀딩스.xlsx 1 1 1 1 1 1
# 1521 휴먼엔.xlsx 1 1 1 1 1 1
# 1522 휴메딕스.xlsx 1 1 1 1 1 1
# 1523 휴비츠.xlsx 1 1 1 1 1 1
# 1524 휴스틸.xlsx 1 1 1 1 1 1
# 1525 휴온스.xlsx 1 1 1 1 1 1
# 1526 휴온스글로벌.xlsx 1 1 1 1 1 1
# 1527 휴온스블러썸.xlsx 1 1 1 1 1 1
# 1528 휴젤.xlsx 1 1 1 1 1 1
# 1529 휴켐스.xlsx 1 1 1 1 1 1
# 1530 흥국에프엔비.xlsx 1 1 1 1 1 1
# 1531 흥아해운.xlsx 1 1 1 1 1 1
# 1532 희림.xlsx 1 1 1 1 1 1
# 1533 힘스.xlsx 1 1 1 1 1 1
# []
# 0

# %%
li = []
for f in error_li:
    df = pd.read_excel(f"./fsdata/{f[1]}", sheet_name=None)
    li.append(f[1]) 
print(li)
# Out:
# ['삼성생명.xlsx']

# %%
df1 = df1.reset_index()
df3 = df3.reset_index()

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df1 = pd.DataFrame({'A':[1], 'C':[3]})
df2 = pd.DataFrame({'A':[1], 'B':[2], 'C':[3], 'D':[4]})
df1.append(df2)
# Out:
#    A  C    B    D
# 0  1  3  NaN  NaN
# 0  1  3  2.0  4.0

# %%
df1.append(df3, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3156/2725901746.py in <module>
# ----> 1 df1.append(df3, ignore_index = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7980             to_concat = [self, other]
#    7981         return (
# -> 7982             concat(
#    7983                 to_concat,
#    7984                 ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     296     )
#     297
# --> 298     return op.get_result()
#     299
#     300
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     514                     obj_labels = obj.axes[1 - ax]
#     515                     if not new_labels.equals(obj_labels):
# --> 516                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     517
#     518                 mgrs_indexers.append((obj._mgr, indexers))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3170
#    3171         if not self.is_unique:
# -> 3172             raise InvalidIndexError(
#    3173                 "Reindexing only valid with uniquely valued Index objects"
#    3174             )
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
def concat_df(df, name, name_pos):
    col_list = []
    for i, col in enumerate(df.columns):
        try:
            int(col[:8])
            col_list.append(i)
        except:
            pass

    nm_df = df.iloc[:, name_pos]
    ye_df =  df.iloc[:, col_list]
    con_df = pd.concat([nm_df, ye_df], axis=1)
    filter_col = ['name']
    for col in con_df.columns[1:]:
        filter_col.append(col[:4])
    
    con_df.columns = filter_col
    con_df.name.iloc[0] = name
    con_df.set_index('name', inplace=True)
    return con_df

# %%
df6.iloc[1]
# Out:
# Unnamed: 0                                              1.0
# Statement of comprehensive income(Unit: KWR)           영업수익
# Unnamed: 2                                              NaN
# 20200101-20201231                               12068903647
# 20190101-20191231                               10228572876
# 20180101-20181231                               13027805266
# Name: 3, dtype: object

# %%
con_df_li = []
for i, f in enumerate(file_list):
    df = pd.read_excel(f"./fsdata/{f}", sheet_name=None)
    
    if df['Data_cis'].iloc[:, 1][0] == "label_ko":
        label_col = 1
    else:
        label_col = 2
        
    if 'Data_is' in df.keys():
        sheet_name = 'Data_is'
    else:
        sheet_name = 'Data_cis'
        
    
    
#     if len(df5) == 0:
#           df4 = df['Data_cf'][df['Data_cf'].iloc[:, label_col].str.contains("매출액").fillna(False)]
    
    print(i, f, len(df5))
    if len(df5) != 1 :
        print("========================================================================Error")

# %%
#

# %%
con_df
# Out:
#                   2020             2019            2018            2017  \
# name
# 자본총계     9626282381126    9181170418766   8424961883357   7656019495485
# 자산총계   114156870956930  104538771055803  98793581956621  94349977199141
# 당기순이익     562555756578     598946530179    538140848972    424964047023
# 매출총이익     748191037815     806882775368    749833212133    594323666429
# 주당이익               NaN              NaN             NaN             NaN
#
#                  2016            2015            2014            2013  \
# name
# 자본총계    7087152831175   6190682621879   5463943894260   3600864866057
# 자산총계   93482189322407  90279548107075  84050063926700  46916890811024
# 당기순이익    518114401855    530471200882    819668197015    305522080841
# 매출총이익    712280655958    696176310892    941140228516    412738282037
# 주당이익              NaN             NaN             NaN             NaN
#
#                  2012            2011            2010
# name
# 자본총계    3261558410213   2954947328300   2183808285926
# 자산총계   43163255892267  39358672617650  30705550891331
# 당기순이익    365873515994             NaN             NaN
# 매출총이익    493613470899    536277321458             NaN
# 주당이익              NaN             NaN             NaN

# %%
# Out:
#     name         2020         2019        2018        2017         2016  \
# 1  당기순이익  18285121577  27788949736  9092446196  6190456821  17543266261
#
#           2015         2014         2013         2012         2011  \
# 1  13158136978  19050210474  15514678383  24650593688  27006653922
#
#           2010
# 1  21616816821

# %%
# is가 없는 경우
df['Data_bs'][df['Data_bs']['Statement of financial position(Unit: KWR)'] == '자본총계']
df['Data_bs'][df['Data_bs']['Statement of financial position(Unit: KWR)'] == '자산총계']
df['Data_cis'][df['Data_cis']['Statement of comprehensive income(Unit: KWR)'].str.contains('당기순이익').fillna(False)]
a = df['Data_cis'][df['Data_cis']['Statement of comprehensive income(Unit: KWR)'].str.contains('주당').fillna(False)]
a[a['Statement of comprehensive income(Unit: KWR)'].str.contains('기본')]
df['Data_cis'][df['Data_cis']['Statement of comprehensive income(Unit: KWR)'] == '매출총이익']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Statement of comprehensive income(Unit: KWR), Unnamed: 2, 20200101-20201231, 20190101-20191231, 20180101-20181231, 20170101-20171231, 20160101-20161231, 20150101-20151231, 20140101-20141231, 20130101-20131231, 20120101-20121231, 20110101-20111231]
# Index: []

# %%
# is가 있는경우
df1 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자본총계']
df2 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자산총계']
df3 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('당기순이익').fillna(False)]
df4 = df['Data_is'][df['Data_is']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
df5 = df['Data_is'][df['Data_is']['Unnamed: 2'] == '매출총이익']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9376/995615969.py in <module>
#       3 df2 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자산총계']
#       4 df3 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('당기순이익').fillna(False)]
# ----> 5 df4 = df['Data_is'][df['Data_is']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
#       6 df5 = df['Data_is'][df['Data_is']['Unnamed: 2'] == '매출총이익']
#
# KeyError: 'Data_is'

# %%
# Out:
# ['BNK금융지주.xlsx',
#  'BYC.xlsx',
#  'DB하이텍.xlsx',
#  'DL.xlsx',
#  'DSR.xlsx',
#  'E1.xlsx',
#  'ESR켄달스퀘어리츠.xlsx',
#  'ES큐브.xlsx',
#  'GS.xlsx',
#  'GS건설.xlsx',
#  'HDC.xlsx',
#  'HDC현대산업개발.xlsx',
#  'HJ중공업.xlsx',
#  'JW생명과학.xlsx',
#  'JW중외제약.xlsx',
#  'JW홀딩스.xlsx',
#  'KB오토시스.xlsx',
#  'KD.xlsx',
#  'KG동부제철.xlsx',
#  'KG케미칼.xlsx',
#  'KH 필룩스.xlsx',
#  'KISCO홀딩스.xlsx',
#  'KPX케미칼.xlsx',
#  'KPX홀딩스.xlsx',
#  'KR모터스.xlsx',
#  'LF.xlsx',
#  'LG.xlsx',
#  'LG디스플레이.xlsx',
#  'LG생활건강.xlsx',
#  'LG에너지솔루션.xlsx',
#  'LG유플러스.xlsx',
#  'LG이노텍.xlsx',
#  'LG전자.xlsx',
#  'LG화학.xlsx',
#  'LIG넥스원.xlsx',
#  'LS.xlsx',
#  'LS네트웍스.xlsx',
#  'LX인터내셔널.xlsx',
#  'MH에탄올.xlsx',
#  'NAVER.xlsx',
#  'NICE.xlsx',
#  'OCI.xlsx',
#  'S-Oil.xlsx',
#  'SBI핀테크솔루션즈.xlsx',
#  'SGC에너지.xlsx',
#  'SG글로벌.xlsx',
#  'SH에너지화학.xlsx',
#  'SIMPAC.xlsx',
#  'SK.xlsx',
#  'SKC.xlsx',
#  'SK가스.xlsx',
#  'SK네트웍스.xlsx',
#  'SK디앤디.xlsx',
#  'SK리츠.xlsx',
#  'SK이노베이션.xlsx',
#  'SK케미칼.xlsx',
#  'SK텔레콤.xlsx',
#  'SNT모티브.xlsx',
#  'SNT에너지.xlsx',
#  'SNT중공업.xlsx',
#  'SNT홀딩스.xlsx',
#  'SPC삼립.xlsx',
#  'STX.xlsx',
#  'STX엔진.xlsx',
#  'STX중공업.xlsx',
#  'SUN&L.xlsx',
#  'TCC스틸.xlsx',
#  'WISCOM.xlsx',
#  '~$DB하이텍.xlsx',
#  '가비아.xlsx',
#  '가온미디어.xlsx',
#  '가온전선.xlsx',
#  '감성코퍼레이션.xlsx',
#  '강남제비스코.xlsx',
#  '강스템바이오텍.xlsx',
#  '강원랜드.xlsx',
#  '강원에너지.xlsx',
#  '갤럭시아머니트리.xlsx',
#  '갤럭시아에스엠.xlsx',
#  '경농.xlsx',
#  '경동나비엔.xlsx',
#  '경동도시가스.xlsx',
#  '경동인베스트.xlsx',
#  '경동제약.xlsx',
#  '경방.xlsx',
#  '경인양행.xlsx',
#  '경창산업.xlsx',
#  '계양전기.xlsx',
#  '고려신용정보.xlsx',
#  '고려아연.xlsx',
#  '고려제강.xlsx',
#  '고바이오랩.xlsx',
#  '골드앤에스.xlsx',
#  '골드퍼시픽.xlsx',
#  '골프존.xlsx',
#  '골프존뉴딘홀딩스.xlsx',
#  '샘표.xlsx',
#  '샘표식품.xlsx',
#  '서린바이오.xlsx',
#  '서부T&D.xlsx',
#  '서산.xlsx',
#  '서연.xlsx',
#  '서연이화.xlsx',
#  '서연탑메탈.xlsx',
#  '서울리거.xlsx',
#  '서울바이오시스.xlsx',
#  '서울반도체.xlsx',
#  '서울옥션.xlsx',
#  '서원인텍.xlsx',
#  '서전기전.xlsx',
#  '서진시스템.xlsx',
#  '서플러스글로벌.xlsx',
#  '서호전기.xlsx',
#  '서흥.xlsx',
#  '서희건설.xlsx',
#  '석경에이티.xlsx',
#  '선도전기.xlsx',
#  '선익시스템.xlsx',
#  '선진뷰티사이언스.xlsx',
#  '성광벤드.xlsx',
#  '성도이엔지.xlsx',
#  '성문전자.xlsx',
#  '성보화학.xlsx',
#  '성신양회.xlsx',
#  '성우테크론.xlsx',
#  '성우하이텍.xlsx',
#  '성창기업지주.xlsx',
#  '성창오토텍.xlsx',
#  '세경하이테크.xlsx',
#  '세기상사.xlsx',
#  '세동.xlsx',
#  '세방.xlsx',
#  '세방전지.xlsx',
#  '세보엠이씨.xlsx',
#  '세아베스틸.xlsx',
#  '세아제강지주.xlsx',
#  '세아특수강.xlsx',
#  '세아홀딩스.xlsx',
#  '세영디앤씨.xlsx',
#  '세우글로벌.xlsx',
#  '세운메디칼.xlsx',
#  '세원이앤씨.xlsx',
#  '세이브존I&C.xlsx',
#  '세종공업.xlsx',
#  '세종메디칼.xlsx',
#  '세종텔레콤.xlsx',
#  '세진중공업.xlsx',
#  '세진티에스.xlsx',
#  '세코닉스.xlsx',
#  '세틀뱅크.xlsx',
#  '센트랄모텍.xlsx',
#  '센트럴인사이트.xlsx',
#  '셀루메드.xlsx',
#  '셀리버리.xlsx',
#  '셀바스AI.xlsx',
#  '셀바스헬스케어.xlsx',
#  '셀트리온제약.xlsx',
#  '셀트리온헬스케어.xlsx',
#  '소프트센.xlsx',
#  '손오공.xlsx',
#  '솔고바이오.xlsx',
#  '솔루스첨단소재.xlsx',
#  '솔루에타.xlsx',
#  '솔루엠.xlsx',
#  '솔본.xlsx',
#  '솔브레인.xlsx',
#  '솔브레인홀딩스.xlsx',
#  '솔트룩스.xlsx',
#  '수산아이앤티.xlsx',
#  '수산중공업.xlsx',
#  '수성이노베이션.xlsx',
#  '수젠텍.xlsx',
#  '슈프리마.xlsx',
#  '슈프리마아이디.xlsx',
#  '슈프리마에이치큐.xlsx',
#  '슈피겐코리아.xlsx',
#  '스카이문스테크놀로지.xlsx',
#  '스킨앤스킨.xlsx',
#  '스타플렉스.xlsx',
#  '스튜디오드래곤.xlsx',
#  '스튜디오산타클로스.xlsx',
#  '스페코.xlsx',
#  '스포츠서울.xlsx',
#  '시공테크.xlsx',
#  '시그네틱스.xlsx',
#  '시너지이노베이션.xlsx',
#  '시노펙스.xlsx',
#  '시디즈.xlsx',
#  '시스웍.xlsx',
#  '시큐브.xlsx',
#  '시티랩스.xlsx',
#  '신대양제지.xlsx',
#  '신도기연.xlsx',
#  '신도리코.xlsx',
#  '신라교역.xlsx']

# %%
df['Data_bs']
# Out:
#     Unnamed: 0 Statement of financial position(Unit: KWR)    Unnamed: 2  \
# 0          NaN                                   label_ko       comment
# 1          NaN                                        NaN           NaN
# 2          0.0                                         자산           NaN
# 3          1.0                                   Ⅰ.현금및예치금      4,6,7,42
# 4          2.0                            당기손익-공정가치금융자산Ⅱ.      4,6,8,11
# 5          3.0                          Ⅲ.기타포괄손익-공정가치금융자산      4,6,9,13
# 6          4.0                                Ⅳ.상각후원가금융자산     4,6,10,13
# 7          5.0                                Ⅴ.대출채권및수취채권  4,6,12,13,14
# 8          6.0                                   Ⅵ.파생상품자산        4,6,15
# 9          7.0                              Ⅶ.관계기업및공동기업투자            16
# 10         8.0                                     Ⅷ.유형자산            17
# 11         9.0                                     Ⅸ.무형자산            18
# 12        10.0                                    Ⅹ.투자부동산            19
# 13        11.0                                    XI.기타자산            20
# 14        12.0                                       자산총계           NaN
# 15        13.0                                         부채           NaN
# 16        14.0                                     Ⅰ.예수부채        4,6,21
# 17        15.0                                     Ⅱ.차입부채        4,6,22
# 18        16.0                                       Ⅲ.사채        4,6,23
# 19        17.0                                   Ⅳ.파생상품부채        4,6,15
# 20        18.0                                  Ⅴ.순확정급여부채            24
# 21        19.0                                     Ⅵ.충당부채         25,39
# 22        20.0                                  Ⅶ.당기법인세부채            37
# 23        21.0                                  Ⅷ.이연법인세부채            37
# 24        22.0                                     Ⅸ.기타부채        4,6,26
# 25        23.0                                       부채총계           NaN
# 26        24.0                                         자본           NaN
# 27        25.0                          Ⅰ.지배기업소유주에게귀속되는자본           NaN
# 28        26.0                                      1.자본금            27
# 29        27.0                                   2.신종자본증권            27
# 30        28.0                                   3.기타불입자본            27
# 31        29.0                                 4.기타자본구성요소            27
# 32        30.0                                    5.이익잉여금            27
# 33        31.0                                    Ⅱ.비지배지분           NaN
# 34        32.0                                       자본총계           NaN
# 35        33.0                                    부채및자본총계           NaN
#
#            20201231         20191231        20181231        20171231  \
# 0       ('연결재무제표',)      ('연결재무제표',)     ('연결재무제표',)     ('연결재무제표',)
# 1               NaN              NaN             NaN             NaN
# 2               NaN              NaN             NaN             NaN
# 
# 31      2190823969     23958713189     23363971072     25972578211
# 32   4101672141880   3650494987472   3216741018338   2461118487849
# 33    304534448701    304466487683    698260578107     99851000000
# 34   7087152831175   6190682621879   5463943894260   3600864866057
# 35  93482189322407  90279548107075  84050063926700  46916890811024
#
#           20121231        20111231        20101231
# 0      ('연결재무제표',)     ('연결재무제표',)     ('연결재무제표',)
# 1              NaN             NaN             NaN
# 2              NaN             NaN             NaN
# 3    2143271973711   2595546725278   1238488915665
# 4     808416922350    374800493947    341973246440
# 5              NaN             NaN             NaN
# 6              NaN             NaN             NaN
# 7   32201826417135  28737076851970  22961708496817
# 8     101449091701    149075590873    193762024652
# 9              NaN             NaN             NaN
# 10    416435557727    412636877446    318804400501
# 11    122054869082     24101550319     10684058961
# 12     75235207341     47962385458     40651517142
# 13     92560194078     52658019188      9040164817
# 14  43163255892267  39358672617650  30705550891331
# 15             NaN             NaN             NaN
# 16  28602191843523  24991337377268  18665284823975
# 17   4428156539259   4638062089721   3787359926404
# 18   4128490838398   3618063356194   2646260680339
# 19     73310282308     82827935548    132227275645
# 20      1715337415     16574509040             NaN
# 21     28899970847     30846417049     19612800766
# 22     37864295761     71540955922     69232029341
# 23     53398467646     31464881226      6695122827
# 24   2547669906897   2923007767382   3195069946108
# 25  39901697482054  36403725289350  28521742605405
# 26             NaN             NaN             NaN
# 27   3261558410213   2954947328300   2183808285926
# 28    966899495000    966899495000    933418250000
# 29             NaN             NaN             NaN
# 30     44751592737     44751592737     -1169555580
# 31     29486797712     35982380854     37994870296
# 32   2220420524764   1907313859709   1213564721210
# 33             NaN             NaN             NaN
# 34   3261558410213   2954947328300   2183808285926
# 35  43163255892267  39358672617650  30705550891331

# %%
for f in file_list[:1]:
    print(f)
    df = pd.read_excel(f"./fsdata/{f}", sheet_name=None)
    df1 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자본총계']
    df2 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자산총계']
    df3 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('당기순이익').fillna(False)]
    if 'Data_is' in df.keys():
        df4 = df['Data_is'][df['Data_is']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
    else:
        df4 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
    if 'Data_is' in df.keys():
        df5 = df['Data_is'][df['Data_is']['Unnamed: 2'] == '매출총이익']
    else:
        df5 = df['Data_cis'][df['Data_cis']['Unnamed: 2'] == '매출총이익']
    print(df1, df2, df3)
# Out:
# BNK금융지주.xlsx
# Empty DataFrame
# Columns: [Unnamed: 0, Statement of financial position(Unit: KWR), Unnamed: 2, 20201231, 20191231, 20181231, 20171231, 20161231, 20151231, 20141231, 20131231, 20121231, 20111231, 20101231]
# Index: []

# %%
'Data_is' in df.keys()
# Out:
# True

# %%
df.keys()
# Out:
# dict_keys(['Data_bs', 'Labels_bs', 'Data_cis', 'Labels_cis', 'Data_cf', 'Labels_cf'])

# %%
lambda x: 'a' x
# Out:
# <function __main__.<lambda>(x)>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("./fsdata/LG.xlsx", sheet_name=None)
df5 = df['Data_is'][df['Data_is'].iloc[:, 2].isin(['기본/희석주당순이익'])]

# %%
df5 = df5.drop(df5.index[1])

# %%
df5
# Out:
#     Unnamed: 0  \
# 24        22.0
#
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
# 24  entity00120021_udf_IS_2017113141813626_udf_IS_...
#
#     Unnamed: 2                               Unnamed: 3        Unnamed: 4  \
# 24  기본/희석주당순이익  Basic/Diluted earnings (loss) per share  손익계산서 [abstract]
#
#       Unnamed: 5  Unnamed: 6  Unnamed: 7 20200101-20201231 20190101-20191231  \
# 24  주당이익(단위 : 원)  계속영업과 중단영업  기본/희석주당순이익              8338              6143
#
#    20180101-20181231 20170101-20171231 20160101-20161231 20150101-20151231  \
# 24             10603             13630              6114              5371
#
#    20140101-20141231 20130101-20131231 20120101-20121231 20110101-20111231  \
# 24               NaN        5097000000        5336000000               NaN
#
#    20100101-20101231 20090101-20091231
# 24               NaN               NaN

# %%
import os
path = "./fsdata"
file_list = os.listdir(path)
file_list
# Out:
# ['BNK금융지주.xlsx',
#  'BYC.xlsx',
#  'DB하이텍.xlsx',
#  'DL.xlsx',
#  'DSR.xlsx',
#  'E1.xlsx',
#  'ESR켄달스퀘어리츠.xlsx',
#  'ES큐브.xlsx',
#  'GS.xlsx',
#  'GS건설.xlsx',
#  'HDC.xlsx',
#  'HDC현대산업개발.xlsx',
#  'HJ중공업.xlsx',
#  'JW생명과학.xlsx',
#  'JW중외제약.xlsx',
#  'JW홀딩스.xlsx',
#  'KB오토시스.xlsx',
#  'KD.xlsx',
#  'KG동부제철.xlsx',
#  'KG케미칼.xlsx',
#  'KH 필룩스.xlsx',
#  'KISCO홀딩스.xlsx',
#  'KPX케미칼.xlsx',
#  'KPX홀딩스.xlsx',
#  'KR모터스.xlsx',
#  'LF.xlsx',
#  'LG.xlsx',
#  'LG디스플레이.xlsx',
#  'LG생활건강.xlsx',
#  'LG에너지솔루션.xlsx',
#  'LG유플러스.xlsx',
#  'LG이노텍.xlsx',
#  'LG전자.xlsx',
#  'LG화학.xlsx',
#  'LIG넥스원.xlsx',
#  'LS.xlsx',
#  'LS네트웍스.xlsx',
#  'LX인터내셔널.xlsx',
#  'MH에탄올.xlsx',
#  'NAVER.xlsx',
#  'NICE.xlsx',
#  'OCI.xlsx',
#  'S-Oil.xlsx',
#  'SBI핀테크솔루션즈.xlsx',
#  'SGC에너지.xlsx',
#  'SG글로벌.xlsx',
#  'SH에너지화학.xlsx',
#  'SIMPAC.xlsx',
#  'SK.xlsx',
#  'SKC.xlsx',
#  'SK가스.xlsx',
#  'SK네트웍스.xlsx',
#  'SK디앤디.xlsx',
#  'SK리츠.xlsx',
#  'SK이노베이션.xlsx',
#  'SK케미칼.xlsx',
#  'SK텔레콤.xlsx',
#  'SNT모티브.xlsx',
# ...

# %%
'보통주 기본주당순이익' in per_li
# Out:
# True

# %%
           
#             if len(df5) > 1:
#                 df5 = df['Data_is'][df['Data_is'].iloc[:, 2].isin(per_li)]
#                 if len(df5) > 1:
#                     df5 = df['Data_is'][df['Data_is'].iloc[:, 2].isin(per_li)]
#             elif len(df5) == 0:
#                 df5 = df['Data_is'][df['Data_is'].iloc[:, 2].str.contains('주당순이익').fillna(False)]
#                 if len(df5) > 1:
#                     df5 = df['Data_is'][df['Data_is'].iloc[:, 2].isin(per_li)]
#                     if len(df5) > 1 and f == 'LG.xlsx':
#                         df5 = df5.drop(df5.index[1])
#                 else:
#                     df5 = df['Data_is'][df['Data_is'].iloc[:, 2].isin(per_li)]
                        
      
            
#             df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('주당이익').fillna(False)]
#             if len(df5) > 1:
#                 df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(per_li)]
#                 if len(df5) > 1:
#                     df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(per_li)]
#             elif len(df5) == 0:
#                 df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('주당순이익').fillna(False)]       
#                 if len(df5) > 1:
#                     df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(per_li)]
#                 elif len(df5) == 0:
#                     df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('주당손익').fillna(False)]
#                     if len(df5) > 1:
#                         df5 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(per_li)]

# %%
# 자본총계, 자산총계, 당기순이익, 매출총이익
if df['Data_bs'].iloc[:, 1][0] == "label_ko":
        name_pos = 1
        df1 = df['Data_bs'][df['Data_bs'].iloc[:, 1] == '자본총계']
    else:
        name_pos = 2
        df1 = df['Data_bs'][df['Data_bs'].iloc[:, 2] == '자본총계']
        
    if df['Data_bs'].iloc[:, 1][0] == "label_ko":
        df2 = df['Data_bs'][df['Data_bs'].iloc[:, 1] == '자산총계']
    else:
        df2 = df['Data_bs'][df['Data_bs'].iloc[:, 2] == '자산총계']
        
    if df['Data_cis'].iloc[:, 1][0] == "label_ko":
        df3 = df['Data_cis'][df['Data_cis'].iloc[:, 1].str.contains('당기순이익').fillna(False)]
        
    else:
        df3 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('당기순이익').fillna(False)]
        if len(df3) > 1:
            df3 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(['당기순이익(손실)', '당기순이익'])]
        if len(df3.values) == 0:
            df3 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(['당기순손익', '당기순손실', '당기의 순이익'])]
            if len(df3.values) == 0:
                df3 = df['Data_cf'][df['Data_cf'].iloc[:, 2].isin(['당기순이익(손실)'])]
                if len(df3.values) == 0:
                    df3 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('당기손익').fillna(False)]
        if len(df3) > 1:
            df3 = df3.drop(df3.index[1])
            
    if df['Data_cis'].iloc[:, 1][0] == "label_ko":
        if 'Data_is' in df.keys():
            df4 = df['Data_is'][df['Data_is'].iloc[:, 1].str.contains('매출총이익').fillna(False)]
        else:
            df4 = df['Data_cis'][df['Data_cis'].iloc[:, 1].str.contains('매출총이익').fillna(False)]
            if len(df4) == 0:
                df4 = df['Data_cis'][df['Data_cis'].iloc[:, 1].str.contains('영업이익').fillna(False)]
    else:
        if 'Data_is' in df.keys():
            df4 = df['Data_is'][df['Data_is'].iloc[:, 2].str.contains('매출총이익').fillna(False)]
            if len(df4) == 0:
                df4 = df['Data_is'][df['Data_is'].iloc[:, 2].str.contains('영업이익').fillna(False)]
        else:
            df4 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('매출총이익').fillna(False)]
            if len(df4) == 0:
                df4 = df['Data_cis'][df['Data_cis'].iloc[:, 2].str.contains('영업이익').fillna(False)]
                if len(df4) > 1:
                    df4 = df['Data_cis'][df['Data_cis'].iloc[:, 2].isin(['영업이익', '영업이익(손실)'])]

# %%
df['Data_cis'].iloc[:, 2]
# Out:
# 0                               label_ko
# 1                                    NaN
# 2                                수익(매출액)
# 3                                   매출원가
# 4                                  매출총이익
# 5                                판매비와관리비
# 6                               영업이익(손실)
# 7                                  지분법손실
# 8                                   금융수익
# 9                                   금융비용
# 10                               기타영업외수익
# 11                               기타영업외비용
# 12                       법인세비용차감전순이익(손실)
# 13                                 법인세비용
# 14                            계속영업이익(손실)
# 15                            중단영업이익(손실)
# 16                            계속영업이익(손실)
# 17                            중단영업이익(손실)
# 18            지배기업의 소유주에게 귀속되는 당기순이익(손실)
# 19                 비지배지분에 귀속되는 당기순이익(손실)
# 20                                기타포괄손익
# 21           당기손익으로 재분류되지 않는항목(세후기타포괄손익)
# 22                     자산재평가손익(세후기타포괄손익)
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, [D431410] Statement of comprehensive income, by function of expense - Consolidated financial statements (Unit: KRW), Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, 20180101-20181231, 20170101-20171231]
# Index: []

# %%
per_li = ['기본주당이익', '기본주당이익(손실)', '계속영업 보통주 기본 및 희석주당이익', '계속영업기본주당이익(손실)', '기본및희석주당순이익(손실)', '기본 및 희석 보통주당이익' \
            ,'계속영업 기본주당이익(손실)', '계속영업기본주당이익', '보통주 기본주당이익', '기본/희석주당순이익', '보통주기본주당순이익', '계속영업 기본및희석주당순이익(손실)' \
            , '기본주당이익', '기본주당이익(손실)', '계속영업 보통주 기본 및 희석주당이익', '계속영업기본주당이익(손실)', '기본및희석주당순이익(손실)', '기본 및 희석 보통주당이익' \
            ,'보통주 기본 및 희석주당계속영업손실', '기본주당이익', '기본주당이익(손실)', '보통주 기본주당순이익', '지배기업소유주 기본 주당이익', '기본및희석주당이익' \
            ,'계속영업기본및희석주당이익(손실)', '계속영업주당순이익(손실)', '보통주 기본 및 희석주당손익', '보통주 기본 및 희석주당이익(손실)', '기본 주당순이익' \
            ,'기본 및 희석주당이익(손실)', '기본주당순이익(손실)', '보통주 기본주당손익', '계속사업보통주기본주당순이익(손실)', '기본주당손익', '기본 및 희석주당손익' \
            ,'기본주당순이익', '기본 및 희석보통주당이익', '기본주당순손실', '계속사업 기본 및 희석주당이익(손실)', '기본주당분기순이익(손실)', '기본주당계속영업손실' \
            ,'기본보통주당이익(손실)', '기본 및 희석 주당 계속영업이익(손실)', '계속영업 기본 및 희석 주당이익(손실)', '기본및희석주당순이익_계속영업', '1.기본주당이익(손실)' \
            ,'기본주당손실', '기본 및 희석 주당순손실'
    
         ]

# %%
for i, f in enumerate(file_list[:1]):
    df = pd.read_excel(f"./fsdata/{f}", sheet_name=None)
    
    if df['Data_cis'].iloc[:, 1][0] == "label_ko":
        label_col = 1
    else:
        label_col = 2

    if 'Data_is' in df.keys():
        sheet_name = 'Data_is'
    else:
        sheet_name = 'Data_cis'
           
    df1 = df['Data_bs'][df['Data_bs'].iloc[:, label_col] == '자본총계']
    df2 = df['Data_bs'][df['Data_bs'].iloc[:, label_col] == '자산총계']
    
    
    df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].str.contains('당기순이익').fillna(False)]
    if len(df3) > 1:
        df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].isin(['당기순이익(손실)', '당기순이익', '당기순손익', '당기순손실'])]
        if len(df3) == 0:
            df3 = df['Data_cf'][df['Data_cf'].iloc[:, label_col].isin(['당기순이익(손실)'])]
    elif len(df3) == 0:
        df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].isin(['당기순손익', '당기순손실', '당기의 순이익', '계속영업이익(손실)'])]
        if len(df3) == 0:
            df3 = df['Data_cis'][df['Data_cis'].iloc[:, label_col].str.contains('당기손익').fillna(False)]
    if len(df3) > 1:
        df3 = df3[df3.isna().sum(axis = 1) == df3.isna().sum(axis = 1).min()]
        
    df4 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('매출총이익').fillna(False)]
    if len(df4) == 0:
        df4 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('영업이익').fillna(False)]
        if len(df4) > 1:
            df4 = df[sheet_name][df[sheet_name].iloc[:, label_col].isin(['영업이익', '영업이익(손실)'])]
              
                
    df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('주당이익').fillna(False)]
    df5 =
    if len(df5) > 1:
        df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].isin(per_li)]
    elif len(df5) == 0:
        df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('주당순이익').fillna(False)]       
        if len(df5) > 1:
            df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].isin(per_li)]
        elif len(df5) == 0:
            df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].str.contains('주당손익').fillna(False)]
            if len(df5) > 1:
                df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].isin(per_li)]
            else:
                df5 = df[sheet_name][df[sheet_name].iloc[:, label_col].isin(per_li)]
    if len(df5) == 2:
        df5 = df5[df5.isna().sum(axis = 1) == df5.isna().sum(axis = 1).min()]
    print(df5)       
    if len(df5) != 1:
        li = []
        for i in range(df5.shape[1]):
            li.append(np.nan)
        df5.loc[1] = li
    
    df1 = concat_df(df1, '자본총계', label_col)
    df2 = concat_df(df2, '자산총계', label_col)
    df3 = concat_df(df3, '당기순이익', label_col)
    df4 = concat_df(df4, '매출총이익', label_col)
    df5 = concat_df(df5, '주당이익', label_col)
    con_df = pd.concat([df1, df2, df3, df4, df5])
    # print(i, f, len(df1), len(df2), len(df3), len(df4), len(df5))
#     if len(df3) != 1:
#         print(i, f, len(df3))
# Out:
#     Unnamed: 0 Statement of comprehensive income(Unit: KWR) Unnamed: 2  \
# 45        43.0                                     XVI.주당이익        NaN
#
#    20200101-20201231 20190101-20191231 20180101-20181231 20170101-20171231  \
# 45               NaN               NaN               NaN               NaN
#
#    20160101-20161231 20150101-20151231 20140101-20141231 20130101-20131231  \
# 45               NaN               NaN               NaN               NaN
#
#    20120101-20121231 20110101-20111231
# 45               NaN               NaN
#     Unnamed: 0  \
# 30        28.0
#
#    [D431410] Statement of comprehensive income, by function of expense - Consolidated financial statements (Unit: KRW)  \
# 30  ifrs-full_BasicEarningsLossPerShareFromContinu...
#
#      Unnamed: 2                                         Unnamed: 3  \
# 30  보통주 기본주당순이익  Basic earnings (loss) per share from continuin...
#
#             Unnamed: 4       Unnamed: 5  Unnamed: 6   Unnamed: 7  \
# ...

# %%
con_df
# Out:
#                2020          2019          2018          2017          2016  \
# name
# 자본총계   452668025243  434327453651  407403446983  399338246383  393851102985
# 자산총계   679134863796  693882852856  738431267101  745823200349  733018517741
# 당기순이익   18285121577   27788949736    9092446196    6190456821   17543266261
# 매출총이익   68752583286   69419560942   73823175539   69367589770   67513620002
# 주당이익          21904         33265         10891          7414         20995
#
#                2015          2014          2013          2012          2011  \
# name
# 자본총계   378117332074  365429628226  347934102717  333347838071  308809429007
# 자산총계   691464608847  608388100986  525157537563  505456934059  477929171533
# 당기순이익   13158136978   19050210474   15514678383   24650593688   27006653922
# 매출총이익   71084009222   74076766980   73498210410   80736775078   80984055596
# 주당이익          15770         22819         24697         39163         42935
#
#                2010          2009
# ...

# %%
def concat_df(df, name, name_pos):
    col_list = []
    for i, col in enumerate(df.columns):
        try:
            int(col[:8])
            col_list.append(i)
        except:
            pass

    nm_df = df.iloc[:, name_pos]
    ye_df =  df.iloc[:, col_list]
    con_df = pd.concat([nm_df, ye_df], axis=1)
    filter_col = ['name']
    for col in con_df.columns[1:]:
        filter_col.append(col[:4])
    
    con_df.columns = filter_col
    con_df.name.iloc[0] = name
    con_df.set_index('name', inplace=True)
    return con_df

# %%
df1
# Out:
#    name         2018          2017        2016
# 1  자본총계  35825802786  -28004954084  1723380380

# %%
# Out:
#     name         2020         2019        2018        2017         2016  \
# 1  당기순이익  18285121577  27788949736  9092446196  6190456821  17543266261
#
#           2015         2014         2013         2012         2011  \
# 1  13158136978  19050210474  15514678383  24650593688  27006653922
#
#           2010
# 1  21616816821

# %%
con_df
# Out:
#     name         2020         2019        2018        2017         2016  \
# 1  당기순이익  18285121577  27788949736  9092446196  6190456821  17543266261
#
#           2015         2014         2013         2012         2011  \
# 1  13158136978  19050210474  15514678383  24650593688  27006653922
#
#           2010
# 1  21616816821

# %%
merge_df = pd.merge(df1,df2, how='outer')
merge_df = pd.merge(merge_df, df3, how='outer')
merge_df
# Out:
#    Unnamed: 0  \
# 0        50.0
# 1        18.0
# 2        14.0
#
#   [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)  \
# 0                                   ifrs-full_Equity
# 1                                   ifrs-full_Assets
# 2                                                NaN
#
#   Unnamed: 2     Unnamed: 3          Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 0       자본총계   Total equity    재무상태표 [abstract]  자본 [abstract]       자본총계
# 1       자산총계   Total assets    재무상태표 [abstract]  자산 [abstract]       자산총계
# 2  당기순이익(손실)  Profit (loss)  포괄손익계산서 [abstract]      당기순이익(손실)        NaN
#
#    Unnamed: 7  Unnamed: 8      20201231  ...  20190101-20191231  \
# 0         NaN         NaN  4.526680e+11  ...                NaN
# 1         NaN         NaN  6.791349e+11  ...                NaN
# 2         NaN         NaN           NaN  ...        27788949736
#
# ...

# %%
df['Data_bs'].columns.str.contains('Unnamed')
# Out:
# array([ True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
df = pd.read_excel('./fsdata/BNK금융지주.xlsx', sheet_name=None)
col_list = []
for col in df['Data_bs'].columns.to_list():
    if col[:7] == 'Unnamed':
        col_list ==
# Out:
# Unnamed: 0
# Statement of financial position(Unit: KWR)
# Unnamed: 2
# 20201231
# 20191231
# 20181231
# 20171231
# 20161231
# 20151231
# 20141231
# 20131231
# 20121231
# 20111231
# 20101231

# %%
# is가 없는 경우
df['Data_bs'][df['Data_bs']['Statement of financial position(Unit: KWR)'] == '자본총계']
df['Data_bs'][df['Data_bs']['Statement of financial position(Unit: KWR)'] == '자산총계']
df['Data_cis'][df['Data_cis']['Statement of comprehensive income(Unit: KWR)'].str.contains('당기순이익').fillna(False)]
a = df['Data_cis'][df['Data_cis']['Statement of comprehensive income(Unit: KWR)'].str.contains('주당').fillna(False)]
a[a['Statement of comprehensive income(Unit: KWR)'].str.contains('기본')]
df['Data_cis'][df['Data_cis']['Statement of comprehensive income(Unit: KWR)'] == '매출총이익']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Statement of comprehensive income(Unit: KWR), Unnamed: 2, 20200101-20201231, 20190101-20191231, 20180101-20181231, 20170101-20171231, 20160101-20161231, 20150101-20151231, 20140101-20141231, 20130101-20131231, 20120101-20121231, 20110101-20111231]
# Index: []

# %%
# is가 있는경우
df1 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자본총계']
df2 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자산총계']
df3 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('당기순이익').fillna(False)]
df4 = df['Data_is'][df['Data_is']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
df5 = df['Data_is'][df['Data_is']['Unnamed: 2'] == '매출총이익']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9376/995615969.py in <module>
#       3 df2 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자산총계']
#       4 df3 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('당기순이익').fillna(False)]
# ----> 5 df4 = df['Data_is'][df['Data_is']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
#       6 df5 = df['Data_is'][df['Data_is']['Unnamed: 2'] == '매출총이익']
#
# KeyError: 'Data_is'

# %%
# Out:
# ['BNK금융지주.xlsx',
#  'BYC.xlsx',
#  'DB하이텍.xlsx',
#  'DL.xlsx',
#  'DSR.xlsx',
#  'E1.xlsx',
#  'ESR켄달스퀘어리츠.xlsx',
#  'ES큐브.xlsx',
#  'GS.xlsx',
#  'GS건설.xlsx',
#  'HDC.xlsx',
#  'HDC현대산업개발.xlsx',
#  'HJ중공업.xlsx',
#  'JW생명과학.xlsx',
#  'JW중외제약.xlsx',
#  'JW홀딩스.xlsx',
#  'KB오토시스.xlsx',
#  'KD.xlsx',
#  'KG동부제철.xlsx',
#  'KG케미칼.xlsx',
#  'KH 필룩스.xlsx',
#  'KISCO홀딩스.xlsx',
#  'KPX케미칼.xlsx',
#  'KPX홀딩스.xlsx',
#  'KR모터스.xlsx',
#  'LF.xlsx',
#  'LG.xlsx',
#  'LG디스플레이.xlsx',
#  'LG생활건강.xlsx',
#  'LG에너지솔루션.xlsx',
#  'LG유플러스.xlsx',
#  'LG이노텍.xlsx',
#  'LG전자.xlsx',
#  'LG화학.xlsx',
#  'LIG넥스원.xlsx',
#  'LS.xlsx',
#  'LS네트웍스.xlsx',
#  'LX인터내셔널.xlsx',
#  'MH에탄올.xlsx',
#  'NAVER.xlsx',
#  'NICE.xlsx',
#  'OCI.xlsx',
#  'S-Oil.xlsx',
#  'SBI핀테크솔루션즈.xlsx',
#  'SGC에너지.xlsx',
#  'SG글로벌.xlsx',
#  'SH에너지화학.xlsx',
#  'SIMPAC.xlsx',
#  'SK.xlsx',
#  'SKC.xlsx',
#  'SK가스.xlsx',
#  'SK네트웍스.xlsx',
#  'SK디앤디.xlsx',
#  'SK리츠.xlsx',
#  'SK이노베이션.xlsx',
#  'SK케미칼.xlsx',
#  'SK텔레콤.xlsx',
#  'SNT모티브.xlsx',
# ...

# %%
df['Data_bs']
# Out:
#     Unnamed: 0 Statement of financial position(Unit: KWR)    Unnamed: 2  \
# 0          NaN                                   label_ko       comment
# 1          NaN                                        NaN           NaN
# 2          0.0                                         자산           NaN
# 3          1.0                                   Ⅰ.현금및예치금      4,6,7,42
# 4          2.0                            당기손익-공정가치금융자산Ⅱ.      4,6,8,11
# 5          3.0                          Ⅲ.기타포괄손익-공정가치금융자산      4,6,9,13
# 6          4.0                                Ⅳ.상각후원가금융자산     4,6,10,13
# 7          5.0                                Ⅴ.대출채권및수취채권  4,6,12,13,14
# 8          6.0                                   Ⅵ.파생상품자산        4,6,15
# 9          7.0                              Ⅶ.관계기업및공동기업투자            16
# 10         8.0                                     Ⅷ.유형자산            17
# 11         9.0                                     Ⅸ.무형자산            18
# ...

# %%
for f in file_list[:1]:
    print(f)
    df = pd.read_excel(f"./fsdata/{f}", sheet_name=None)
    df1 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자본총계']
    df2 = df['Data_bs'][df['Data_bs']['Unnamed: 2'] == '자산총계']
    df3 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('당기순이익').fillna(False)]
    if 'Data_is' in df.keys():
        df4 = df['Data_is'][df['Data_is']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
    else:
        df4 = df['Data_cis'][df['Data_cis']['Unnamed: 2'].str.contains('기본주당이익').fillna(False)]
    if 'Data_is' in df.keys():
        df5 = df['Data_is'][df['Data_is']['Unnamed: 2'] == '매출총이익']
    else:
        df5 = df['Data_cis'][df['Data_cis']['Unnamed: 2'] == '매출총이익']
    print(df1, df2, df3)
# Out:
# BNK금융지주.xlsx
# Empty DataFrame
# Columns: [Unnamed: 0, Statement of financial position(Unit: KWR), Unnamed: 2, 20201231, 20191231, 20181231, 20171231, 20161231, 20151231, 20141231, 20131231, 20121231, 20111231, 20101231]
# Index: []

# %%
'Data_is' in df.keys()
# Out:
# True

# %%
df.keys()
# Out:
# dict_keys(['Data_bs', 'Labels_bs', 'Data_cis', 'Labels_cis', 'Data_cf', 'Labels_cf'])

# %%
lambda x: 'a' x
# Out:
# <function __main__.<lambda>(x)>

# %%
# !pip install OpenDartReader

# %%
import OpenDartReader
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dart_fss as dart

# %%
api_key = 'e0646f27a0bad27c49544a269362fd7e844913b0'
dart.set_api_key(api_key=api_key)
# Out:
# 'e0646f27a0bad27c49544a269362fd7e844913b0'

# %%
# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자 검색
samsung = corp_list.find_by_corp_name('삼성생명', exactly=True)[0]

# 2012년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20100101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
fs.save()
# Out:
# Output()
# Output()
# Output()
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# 'D:\\fintech\\Bit_Project1\\fsdata\\00126256_annual.xlsx'

# %%
df = pd.read_csv('data/data_3322_20220211.csv', encoding = 'euc-kr')

# %%
stock_code = code = df['단축코드'].iloc[df[df['한글 종목명'].str.contains('우선주')].index]

# %%
df = pd.read_csv('./data/data_3322_20220211.csv', encoding='euc-kr')
df

# %%
# '11013'=1분기보고서, '11012' =반기보고서, '11014'=3분기보고서, '11011'=사업보고서
reprt_code = ['11013', '11012', '11014', '11011']

# %%
# 2020-07-01 부터 현재까지 모든 회사의 정기보고서
df = dart.finstate('삼성전자', 2019)

# %%
# df.to_excel(f"stock_excel_files/{name}.xlsx")
df

# %%
df.단축코드[]
# Out:
# 0       098120
# 1       131100
# 2       009520
# 3       095570
# 4       006840
#          ...
# 2609    000547
# 2610    000540
# 2611    003280
# 2612    037440
# 2613    238490
# Name: 단축코드, Length: 2614, dtype: object

# %%
# !pip install dart-fss
# Out:
# ...
#   Created wheel for arelle: filename=arelle-2.2-py3-none-any.whl size=2060307 sha256=1d545d3f581a8117234c6de5cf0c997abaf4ba6df9728abc7026d6dd57ff644b
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\ae\ea\80\69a7c9134cb71ed0d6d427cbba1918e8a20be166b616558bd1
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=39e0d87bb5149f9a0033e6a229d4470a5db252b801482692ea0794241031fc5d
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\ae\e7\76\7dd44644d065268ab0e1b4fa2e802fa4bb0157717b7d6c6d92
# ...
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11260 sha256=86675b5f18a24d446100fd105842fdf6d64d1711e166acc076aa6fa9fdd16636
#   Stored in directory: c:\users\bitcamp\appdata\local\pip\cache\wheels\bb\85\47\b7c7338ab52808105f937bd8c04aec5d98a543311ac2c8bed2
# ...

# %%
import dart_fss as dart

api_key='e0646f27a0bad27c49544a269362fd7e844913b0'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자 검색
samsung = corp_list.find_by_stock_code('098120')

# 2012년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20100101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
fs.save()
# Out:
# Output()
# Output()
# Output()
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7076/183011362.py in <module>
#      11
#      12 # 2012년부터 연간 연결재무제표 불러오기
# ---> 13 fs = samsung.extract_fs(bgn_de='20100101')
#      14
#      15 # 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
#
# ~\anaconda3\lib\site-packages\dart_fss\corp\corp.py in extract_fs(self, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator, dataset, cumulative)
#     241
#     242          """
# --> 243         return extract(self.corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator, dataset, cumulative)
#
# ~\anaconda3\lib\site-packages\dart_fss\fs\extract.py in extract(corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator, dataset, cumulative)
# ...

# %%
df = pd.read_csv('./data/data_3322_20220211.csv', encoding='euckr')
inds = df[df['한글 종목명'].str.contains('우선주')].index
dfn = df.drop(inds)
names = dfn['한글 종목약명']
names
# Out:
# 0       마이크로컨텍솔
# 1        스카이이앤엠
# 2         포스코엠텍
# 3        AJ네트웍스
# 4         AK홀딩스
#          ...
# 2607     흥국에프엔비
# 2610       흥국화재
# 2611       흥아해운
# 2612         희림
# 2613         힘스
# Name: 한글 종목약명, Length: 2491, dtype: object

# %%
for name in names[830:1660]:
    try:
        company = corp_list.find_by_corp_name(name, exactly=True)[0]
        fs = company.extract_fs(bgn_de='20100101')
        filename = f'{name}.xlsx'
        path = ''
        fs.save(filename=filename)
        print(f"{filename} save succese!")
    except:
        pass
# Out:
# Annual reports:   0%|          | 0/4 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20220124000204', 'corp_code': '00971090', 'corp_name': '샘코', 'stock_code': '263540', 'corp_cls': 'K', 'report_nm': '[기재정정]사업보고서 (2019.12)', 'flr_nm': '샘코', 'rcept_dt': '20220124', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
# ...
